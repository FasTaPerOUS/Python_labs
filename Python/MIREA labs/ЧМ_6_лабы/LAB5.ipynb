# %%
import sympy
import math
x = sympy.symbols('x')
x1 = sympy.symbols('x1')
x2 = sympy.symbols('x2')
m = sympy.symbols('log(x2)')
eps = 0.001
fbeg1 = x1 ** 2 - 2 * m - 1
fbeg2 = x1 ** 2 - 3 * x1 * x2 + 3
f1 = (2 * m + 1) ** 0.5
f2 = x1 / 3 + 1 / x1
print(fbeg1)
print(fbeg2)
print(f1)
print(f2)
# Out:
# -2*log(x2) + x1**2 - 1
# x1**2 - 3*x1*x2 + 3
# (2*log(x2) + 1)**0.5
# x1/3 + 1/x1

# %%
import sympy
import math
x = sympy.symbols('x')
x1 = sympy.symbols('p')
x2 = sympy.symbols('q')
k = sympy.symbols('k')
l = sympy.symbols('l')
m = sympy.symbols('log(x2)')
eps = 0.001
# fbeg1 = x1 ** 2 + x2 ** 2 - 1
# fbeg2 = sympy.sin(x1 - x2) + 0.3 * x1 - 1
# f1 = (-x2 ** 2 + 1) ** 0.5
# f2 = -sympy.asin(1-0.3*x1) + x1 + 1 * math.pi
fbeg1 = x1 + x2 - 1
fbeg2 = sympy.sin(x1**0.5 - x2**0.5) + 0.3 * x1**0.5 - 1
f1 = 1 - x2
f2 = -sympy.asin(1-0.3*x1) + x1 + 1 * math.pi
print(fbeg1)
print(fbeg2)
print(f1)
print(f2)
# Out:
# p + q - 1
# 0.3*p**0.5 + sin(p**0.5 - q**0.5) - 1
# -q + 1
# p + asin(0.3*p - 1) + 3.14159265358979

# %%
min = 99999999
x = -1
arr = []
for i in range(2*1000000):
    x_now = x + i / 1000000
    y_now = (1 - x_now)**0.5
    if (x)
    if min > abs(fbeg2.subs([(x1, x_now), (x2, y_now)])):
        min = fbeg2.subs([(x1, x_now), (x2, y_now)])
        arr = [x_now, y_now]
print(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4f1f302704ad> in <module>()
#       5     x_now = x + i / 1000000
#       6     y_now = (1 - x_now)**0.5
# ----> 7     if min > abs(fbeg2.subs([(x1, x_now), (x2, y_now)])):
#       8         min = fbeg2.subs([(x1, x_now), (x2, y_now)])
#       9         arr = [x_now, y_now]
#
# C:\Anaconda3\lib\site-packages\sympy\core\expr.py in __gt__(self, other)
#     297             if (me.is_complex and me.is_real is False) or \
#     298                     me.has(S.ComplexInfinity):
# --> 299                 raise TypeError("Invalid comparison of complex %s" % me)
#     300             if me is S.NaN:
#     301                 raise TypeError("Invalid NaN comparison")
#
# TypeError: Invalid comparison of complex -2.43209300461663 + 0.737640041768707*I

# %%
xcur1 = xcur2 = 0.2
xnew1 = f1.subs(x2, xcur2)
xnew2 = f2.subs(x1, xcur1)
print(xcur1, xcur2)
print(xnew1, xnew2)
print()
print()
while (abs(xnew1 - xcur1) > eps or abs(xnew2 - xcur2) > eps):
    xcur1, xcur2 = xnew1, xnew2
    xnew1 = f1.subs(x2, xcur2)
    xnew2 = f2.subs(x1, xcur1)
    print(xcur1, xcur2)
    print(xnew1, xnew2)
    print()
print(xnew1)
print(xnew2)
print()
print(fbeg1.subs([(x1, xnew1), (x2, xnew2)]))
print(fbeg2.subs([(x1, xnew1), (x2, xnew2)]))
# Out:
# 0.2 0.2
# 0.979795897113271 2.11896234806786
#
#
# 0.979795897113271 2.11896234806786
# 1.86815455263456*I 3.33746792772402
#
# 1.86815455263456*I 3.33746792772402
# 3.18413130517358*I 2.28089521288461 + 2.64676559798022*I
#
# 3.18413130517358*I 2.28089521288461 + 2.64676559798022*I
# (1 - (2.28089521288461 + 2.64676559798022*I)**2)**0.5 2.45928422238921 + 4.2196672466058*I
#
# (1 - (2.28089521288461 + 2.64676559798022*I)**2)**0.5 2.45928422238921 + 4.2196672466058*I
# (1 - (2.45928422238921 + 4.2196672466058*I)**2)**0.5 3.14159265358979 + (1 - (2.28089521288461 + 2.64676559798022*I)**2)**0.5 - asin(1 - 0.3*(1 - (2.28089521288461 + 2.64676559798022*I)**2)**0.5)
#
# (1 - (2.45928422238921 + 4.2196672466058*I)**2)**0.5 3.14159265358979 + (1 - (2.28089521288461 + 2.64676559798022*I)**2)**0.5 - asin(1 - 0.3*(1 - (2.28089521288461 + 2.64676559798022*I)**2)**0.5)
# ...

# %%
xcur1 = xcur2 = 1
xnew1 = f1.subs(m, math.log(xcur2))
xnew2 = f2.subs(x1, xcur1)
#print(xcur1, xcur2)
#print(xnew1, xnew2)
#print()
#print()
while (abs(xnew1 - xcur1) > eps or abs(xnew2 - xcur2) > eps):
    xcur1, xcur2 = xnew1, xnew2
    xnew1 = f1.subs(m, math.log(xcur2))
    xnew2 = f2.subs(x1, xcur1)
    #print(xcur1, xcur2)
    #print(xnew1, xnew2)
    #print()
print(xnew1)
print(xnew2)
print()
print(fbeg1.subs([(x1, xnew1), (m, math.log(xnew2))]))
print(fbeg2.subs([(x1, xnew1), (x2, xnew2)]))
# Out:
# 1.19333909456949
# 1.23576447933937
#
# 0.000678614263713628
# 0
